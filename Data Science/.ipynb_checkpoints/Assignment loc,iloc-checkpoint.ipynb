# %%
import pandas as pd
data = pd.Series([100, 200, 300, 400], index=['x', 'y', 'z', 'w'])
data.loc['y']
# Out:
# np.int64(200)

# %%
#2
data.iloc[1]
# Out:
# np.int64(200)

# %%
#3
data.loc[["x","w"]]
# Out:
# x    100
# w    400
# dtype: int64

# %%
#4
data.iloc[3]
data.iloc[-1]
# Out:
# np.int64(400)

# %%
#5
data.loc['y':'z']
# Out:
# y    200
# z    300
# dtype: int64

# %%
#6
data=pd.Series([100,200,300,400],
index=[0,1,2,3])
print(data.iloc[2])   #index position
print(data.loc[2])   #label
# Out:
# 300
# 300

# %%
#7
import pandas as pd
data=pd.Series([100,200,300,400],
index=['x','y','z','w'])               
print(data.x)
# Out:
# 100
