# %%
#2
import pandas as pd

# %%
df= pd.read_csv("neet_data.csv")

# %%
df
# Out:
#          created_at  retweet_count               source              user_id  \
# 0      44135.590602            141  Twitter for Android  1250294694937910000
# 1      44135.590405              1   Twitter for iPhone             57059492
# 2      44135.590139            141      Twitter Web App           1016022678
# 3      44135.590058            141  Twitter for Android  1085818329816880000
# 4      44135.589838              0  Twitter for Android  1227501071490110000
# ...             ...            ...                  ...                  ...
# 47376  44134.645544              0  Twitter for Android  1168840190426630000
# 47377  44134.645544           1700  Twitter for Android           1696615807
# 47378  44134.645127            167  Twitter for Android  1313330869113740000
# 47379  44134.644873            270  Twitter for Android  1161551282995380000
# 47380  44134.644606              0  Twitter for Android  1211810532006610000
#
#                     user_name  \
# ...

# %%
df.columns
# Out:
# Index(['created_at', 'retweet_count', 'source', 'user_id', 'user_name',
#        'user_description', 'user_follower_count', 'user_friends_count',
#        'user_location', 'user_verified', 'user_url', 'tweet',
#        'length_of_tweet'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 47381 entries, 0 to 47380
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           47381 non-null  float64
#  1   retweet_count        47381 non-null  int64
#  2   source               47362 non-null  str
#  3   user_id              47381 non-null  int64
#  4   user_name            47380 non-null  str
#  5   user_description     36510 non-null  str
#  6   user_follower_count  47381 non-null  int64
#  7   user_friends_count   47381 non-null  int64
#  8   user_location        26247 non-null  str
#  9   user_verified        47381 non-null  bool
#  10  user_url             9280 non-null   str
#  11  tweet                47381 non-null  str
#  12  length_of_tweet      47381 non-null  int64
# dtypes: bool(1), float64(1), int64(5), str(6)
# memory usage: 4.4 MB

# %%
df.shape
# Out:
# (47381, 13)

# %%
#3
df.sort_values(by="retweet_count",ascending=False)
# Out:
#          created_at  retweet_count               source              user_id  \
# 32860  44143.229178         614304   Twitter for iPhone  1024658968394620000
# 33262  44142.911736         581097  Twitter for Android  1099388669448860000
# 35111  44141.597604         381458      Twitter Web App           2578241503
# 32585  44143.304884         204348   Twitter for iPhone  1103362192169180000
# 38044  44139.763345         192350   Twitter for iPhone             54249914
# ...             ...            ...                  ...                  ...
# 33534  44142.698368              0      Twitter Web App  1301196667887030000
# 33533  44142.698750              0   Twitter for iPhone           2835488103
# 13611  44131.057674              0  Twitter for Android  1207560622273150000
# 33531  44142.700116              0  Twitter for Android   905021614546313000
# 47380  44134.644606              0  Twitter for Android  1211810532006610000
#
# ...

# %%
#4
df.sort_values(by="retweet_count",ascending=False)[
['source','retweet_count','user_name','tweet','created_at','user_url']
    ].head(1)
# Out:
#                    source  retweet_count  \
# 32860  Twitter for iPhone         614304
#
#                                   user_name  \
# 32860  \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
#
#                                                    tweet    created_at  \
# 32860  RT @JoeBiden: America, I\xe2\x80\x99m honored ...  44143.229178
#
#                       user_url
# 32860  https://t.co/cHZdP4uOdu

# %%
#5
df['retweet_count'].nlargest(10).sum()
# Out:
# np.int64(2652225)

# %%
#6
android_df=df[df['source']=='Twitter for Android']
android_df.shape[0]
android_df['retweet_count'].sum()
# Out:
# np.int64(9386742)

# %%
#7
df.sort_values(by='user_follower_count',ascending=False).iloc[0][
['user_name','user_location']
    ]
# Out:
# user_name         NDTV
# user_location    India
# Name: 44355, dtype: object

# %%
#8
import pandas as pd
df= pd.read_csv("neet_data.csv")
df['followers_friend_ratio']=(
    df['user_follower_count']/
    df['user_friends_count']
)
df.head()
# Out:
#      created_at  retweet_count               source              user_id  \
# 0  44135.590602            141  Twitter for Android  1250294694937910000
# 1  44135.590405              1   Twitter for iPhone             57059492
# 2  44135.590139            141      Twitter Web App           1016022678
# 3  44135.590058            141  Twitter for Android  1085818329816880000
# 4  44135.589838              0  Twitter for Android  1227501071490110000
#
#       user_name                                   user_description  \
# 0          Rumi                                                NaN
# 1    Tom Bewick  Proud dad of three & cat, @SussexCCC fan. CEO ...
# 2      Lemonade  Wisdom is knowing the right path to take, Inte...
# 3       The Rus                                                NaN
# 4  Sakshi Yadav                 it's not my attitude it's my style
#
#    user_follower_count  user_friends_count              user_location  \
# ...

# %%
#9
df.isnull().sum()
# Out:
# created_at                    0
# retweet_count                 0
# source                       19
# user_id                       0
# user_name                     1
# user_description          10871
# user_follower_count           0
# user_friends_count            0
# user_location             21134
# user_verified                 0
# user_url                  38101
# tweet                         0
# length_of_tweet               0
# followers_friend_ratio      147
# dtype: int64

# %%
#10
df['user_description'].fillna("twitter user",inplace=True)
# Out:
# C:\Users\verma\AppData\Local\Temp\ipykernel_14208\1876582430.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['user_description'].fillna("twitter user",inplace=True)
# 0                                             twitter user
# 1        Proud dad of three & cat, @SussexCCC fan. CEO ...
# ...

# %%
#11
df.dropna(axis=1, inplace=True)
df.columns
# Out:
# Index(['created_at', 'retweet_count', 'user_id', 'user_follower_count',
#        'user_friends_count', 'user_verified', 'tweet', 'length_of_tweet'],
#       dtype='str')

# %%
#12
df.insert(2,'is allow',True)
df.head
# Out:
# <bound method NDFrame.head of          created_at  retweet_count  is allow              user_id  \
# 0      44135.590602            141      True  1250294694937910000
# 1      44135.590405              1      True             57059492
# 2      44135.590139            141      True           1016022678
# 3      44135.590058            141      True  1085818329816880000
# 4      44135.589838              0      True  1227501071490110000
# ...             ...            ...       ...                  ...
# 47376  44134.645544              0      True  1168840190426630000
# 47377  44134.645544           1700      True           1696615807
# 47378  44134.645127            167      True  1313330869113740000
# 47379  44134.644873            270      True  1161551282995380000
# 47380  44134.644606              0      True  1211810532006610000
#
#        user_follower_count  user_friends_count  user_verified  \
# 0                       14                 180          False
# ...

# %%
#13
df.drop(columns=['tweet'],inplace=True)
df.head
# Out:
# <bound method NDFrame.head of          created_at  retweet_count  is allow              user_id  \
# 0      44135.590602            141      True  1250294694937910000
# 1      44135.590405              1      True             57059492
# 2      44135.590139            141      True           1016022678
# 3      44135.590058            141      True  1085818329816880000
# 4      44135.589838              0      True  1227501071490110000
# ...             ...            ...       ...                  ...
# 47376  44134.645544              0      True  1168840190426630000
# 47377  44134.645544           1700      True           1696615807
# 47378  44134.645127            167      True  1313330869113740000
# 47379  44134.644873            270      True  1161551282995380000
# 47380  44134.644606              0      True  1211810532006610000
#
#        user_follower_count  user_friends_count  user_verified  length_of_tweet
# ...

# %%
#14
df['created_at'] = pd.to_datetime(df['created_at'])
df['month'] = df['created_at'].dt.month
df['year'] = df['created_at'].dt.year
df[['created_at','month','year']].head()
# Out:
#                      created_at  month  year
# 0 1970-01-01 00:00:00.000044135      1  1970
# 1 1970-01-01 00:00:00.000044135      1  1970
# 2 1970-01-01 00:00:00.000044135      1  1970
# 3 1970-01-01 00:00:00.000044135      1  1970
# 4 1970-01-01 00:00:00.000044135      1  1970
